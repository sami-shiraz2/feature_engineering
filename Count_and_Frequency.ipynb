# %%
# !pip install kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-b682bb55-2bcf-4705-be90-c83fe2b8474f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b682bb55-2bcf-4705-be90-c83fe2b8474f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"samishiraz00","key":"46891157b5e279e456473375fee471b9"}'}

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !!kaggle datasets download -d yogeerp/mercedes
# Out:
# ['Downloading mercedes.zip to /content',
#  '',
#  '  0% 0.00/293k [00:00<?, ?B/s]',
#  '',
#  '100% 293k/293k [00:00<00:00, 19.2MB/s]']

# %%
from zipfile import ZipFile
filename="/content/mercedes.zip"

with ZipFile(filename, "r") as zip:
  zip.extractall()
  print("Done")
# Out:
# Done

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("/content/mercedesbenz.csv", usecols=["X1", "X2"])
df.head()
# Out:
#   X1  X2
# 0  v  at
# 1  t  av
# 2  w   n
# 3  t   n
# 4  v   n

# %% [markdown]
# **Count and Frequency Encoding**

# %%
len(df["X1"].unique())
# Out:
# 27

# %%
len(df["X2"].unique())
# Out:
# 44

# %%
for cols in df.columns:
  print(cols, ":" , len(df[cols].unique()), "labels")
# Out:
# X1 : 27 labels
# X2 : 44 labels

# %%
df.X2.value_counts().to_dict()
# Out:
# {'a': 47,
#  'aa': 1,
#  'ac': 13,
#  'ae': 496,
#  'af': 1,
#  'ag': 19,
#  'ah': 4,
#  'ai': 415,
#  'ak': 265,
#  'al': 5,
#  'am': 1,
#  'an': 5,
#  'ao': 20,
#  'ap': 11,
#  'aq': 63,
#  'ar': 1,
#  'as': 1659,
#  'at': 6,
#  'au': 3,
#  'av': 4,
#  'aw': 8,
#  'ay': 54,
#  'b': 21,
#  'c': 1,
#  'd': 18,
#  'e': 81,
#  'f': 87,
#  'g': 12,
#  'h': 6,
#  'i': 25,
#  'j': 1,
#  'k': 25,
#  'l': 1,
#  'm': 367,
#  'n': 137,
#  'o': 1,
#  'p': 4,
#  'q': 5,
#  'r': 153,
#  's': 94,
#  't': 29,
#  'x': 10,
#  'y': 11,
#  'z': 19}

# %%
frequency_X2 = df.X2.value_counts().to_dict()

# %%
df.head()
# Out:
#   X1  X2
# 0  v  at
# 1  t  av
# 2  w   n
# 3  t   n
# 4  v   n

# %%
df.X2 = df.X2.map(frequency_X2)

df.head()
# Out:
#   X1   X2
# 0  v    6
# 1  t    4
# 2  w  137
# 3  t  137
# 4  v  137
